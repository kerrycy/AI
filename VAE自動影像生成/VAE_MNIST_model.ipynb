# %%
#導入所需資料庫
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Model

# %%
#使用(z_mean, z_log_var) 對 z 進行採樣，編碼一個數字的向量。
class Sampling(layers.Layer):

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
#編碼器
latent_dim = 2 #潛在空間的維度：一個平面

#編碼器layer層
encoder_inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 32)   320         ['input_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 7, 7, 64)     18496       ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 7, 7, 64)     36928       ['conv2d_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 64)     36928       ['conv2d_8[0][0]']
#
#  flatten_2 (Flatten)            (None, 3136)         0           ['conv2d_9[0][0]']
#
#  dense_3 (Dense)                (None, 16)           50192       ['flatten_2[0][0]']
#
#  z_mean (Dense)                 (None, 2)            34          ['dense_3[0][0]']
#
#  z_log_var (Dense)              (None, 2)            34          ['dense_3[0][0]']
#
#  sampling_2 (Sampling)          (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 142,932
# Trainable params: 142,932
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#解碼器、layer層
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(7 * 7 * 64, activation="relu")(latent_inputs)
x = layers.Reshape((7, 7, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", padding="same")(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", padding="same")(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 2)]               0
#
#  dense_4 (Dense)             (None, 3136)              9408
#
#  reshape_1 (Reshape)         (None, 7, 7, 64)          0
#
#  conv2d_transpose_3 (Conv2DT  (None, 7, 7, 64)         36928
#  ranspose)
#
#  conv2d_transpose_4 (Conv2DT  (None, 7, 7, 64)         36928
#  ranspose)
#
#  conv2d_transpose_5 (Conv2DT  (None, 14, 14, 64)       36928
#  ranspose)
#
#  conv2d_transpose_6 (Conv2DT  (None, 28, 28, 32)       18464
#  ranspose)
#
#  conv2d_transpose_7 (Conv2DT  (None, 28, 28, 1)        289
#  ranspose)
#
# =================================================================
# Total params: 138,945
# Trainable params: 138,945
# Non-trainable params: 0
# _________________________________________________________________

# %%
#將 VAE 定義為Model自定義train_step
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
#開始訓練
(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
mnist_digits = np.concatenate([x_train, x_test], axis=0)
mnist_digits = np.expand_dims(mnist_digits, -1).astype("float32") / 255

vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())
vae.fit(mnist_digits, epochs=30, batch_size=128)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Epoch 1/30
# 547/547 [==============================] - 111s 200ms/step - loss: 262.2480 - reconstruction_loss: 211.6115 - kl_loss: 2.8101
# Epoch 2/30
# 547/547 [==============================] - 105s 192ms/step - loss: 190.5420 - reconstruction_loss: 185.6401 - kl_loss: 3.3581
# Epoch 3/30
# 547/547 [==============================] - 98s 180ms/step - loss: 185.6978 - reconstruction_loss: 181.7113 - kl_loss: 3.5214
# Epoch 4/30
# 547/547 [==============================] - 97s 178ms/step - loss: 184.0796 - reconstruction_loss: 179.7613 - kl_loss: 3.6211
# Epoch 5/30
# 547/547 [==============================] - 99s 182ms/step - loss: 182.3385 - reconstruction_loss: 178.1621 - kl_loss: 3.6778
# Epoch 6/30
# 547/547 [==============================] - 97s 178ms/step - loss: 180.8032 - reconstruction_loss: 176.5596 - kl_loss: 3.7345
# Epoch 7/30
# 547/547 [==============================] - 96s 176ms/step - loss: 178.9912 - reconstruction_loss: 174.9754 - kl_loss: 3.8167
# Epoch 8/30
# 547/547 [==============================] - 97s 177ms/step - loss: 177.9797 - reconstruction_loss: 173.8461 - kl_loss: 3.8614
# Epoch 9/30
# 547/547 [==============================] - 97s 177ms/step - loss: 177.1845 - reconstruction_loss: 172.9380 - kl_loss: 3.8760
# Epoch 10/30
# 547/547 [==============================] - 97s 177ms/step - loss: 176.3721 - reconstruction_loss: 172.2798 - kl_loss: 3.8845
# Epoch 11/30
# 547/547 [==============================] - 98s 179ms/step - loss: 175.6173 - reconstruction_loss: 171.7490 - kl_loss: 3.8829
# Epoch 12/30
# 547/547 [==============================] - 96s 175ms/step - loss: 175.3241 - reconstruction_loss: 171.1740 - kl_loss: 3.8792
# Epoch 13/30
# 547/547 [==============================] - 96s 175ms/step - loss: 174.7648 - reconstruction_loss: 170.8964 - kl_loss: 3.8718
# Epoch 14/30
# 547/547 [==============================] - 96s 176ms/step - loss: 174.2305 - reconstruction_loss: 170.5649 - kl_loss: 3.8391
# Epoch 15/30
# 547/547 [==============================] - 97s 178ms/step - loss: 173.9199 - reconstruction_loss: 170.1958 - kl_loss: 3.8317
# Epoch 16/30
# 547/547 [==============================] - 96s 176ms/step - loss: 173.7965 - reconstruction_loss: 169.9104 - kl_loss: 3.8178
# Epoch 17/30
# 547/547 [==============================] - 96s 175ms/step - loss: 173.3817 - reconstruction_loss: 169.5500 - kl_loss: 3.7768
# Epoch 18/30
# 547/547 [==============================] - 95s 173ms/step - loss: 173.1323 - reconstruction_loss: 169.3886 - kl_loss: 3.7790
# Epoch 19/30
# 547/547 [==============================] - 95s 174ms/step - loss: 172.8521 - reconstruction_loss: 169.1692 - kl_loss: 3.7609
# Epoch 20/30
# 547/547 [==============================] - 96s 175ms/step - loss: 172.4407 - reconstruction_loss: 168.9062 - kl_loss: 3.7521
# Epoch 21/30
# 547/547 [==============================] - 95s 174ms/step - loss: 172.2238 - reconstruction_loss: 168.6830 - kl_loss: 3.7464
# Epoch 22/30
# 547/547 [==============================] - 95s 174ms/step - loss: 172.5620 - reconstruction_loss: 168.6187 - kl_loss: 3.7383
# Epoch 23/30
# 547/547 [==============================] - 116s 212ms/step - loss: 172.2662 - reconstruction_loss: 168.3914 - kl_loss: 3.7395
# Epoch 24/30
# 547/547 [==============================] - 121s 220ms/step - loss: 172.1288 - reconstruction_loss: 168.2270 - kl_loss: 3.7166
# Epoch 25/30
# 547/547 [==============================] - 108s 198ms/step - loss: 171.4550 - reconstruction_loss: 167.9606 - kl_loss: 3.7447
# Epoch 26/30
# 547/547 [==============================] - 95s 174ms/step - loss: 171.8341 - reconstruction_loss: 167.8517 - kl_loss: 3.7452
# Epoch 27/30
# 547/547 [==============================] - 95s 174ms/step - loss: 171.8139 - reconstruction_loss: 167.7800 - kl_loss: 3.7224
# Epoch 28/30
# 547/547 [==============================] - 96s 175ms/step - loss: 171.3756 - reconstruction_loss: 167.5613 - kl_loss: 3.7410
# Epoch 29/30
# 547/547 [==============================] - 105s 192ms/step - loss: 171.1617 - reconstruction_loss: 167.4545 - kl_loss: 3.7441
# Epoch 30/30
# 547/547 [==============================] - 110s 202ms/step - loss: 171.2990 - reconstruction_loss: 167.3932 - kl_loss: 3.7375

# %%
#儲存模型
vae.save_weights('/content/drive/MyDrive/VAE.h5')

# %%
#輸出結果
import matplotlib.pyplot as plt


def plot_latent_space(vae, n=30, figsize=15):
    # display a n*n 2D manifold of digits
    digit_size = 28
    scale = 1.0
    figure = np.zeros((digit_size * n, digit_size * n))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            z_sample = np.array([[xi, yi]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(digit_size, digit_size)
            figure[
                i * digit_size : (i + 1) * digit_size,
                j * digit_size : (j + 1) * digit_size,
            ] = digit

    plt.figure(figsize=(figsize, figsize))
    start_range = digit_size // 2
    end_range = n * digit_size + start_range
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)
